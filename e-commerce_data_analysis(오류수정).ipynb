# %%
#pandas 라이브러리 호출
import pandas as pd
#고객데이터 불러오기
customer=pd.read_csv("olist_customers_dataset.csv")
#데이터가 잘 반입되었는지 확인
customer.head()
customer[:]
# Out:
#                             customer_id                customer_unique_id  \
# 0      06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 1      18955e83d337fd6b2def6b18a428ac77  290c77bc529b7ac935b93aa66c333dc3
# 2      4e7b3e00288586ebd08712fdd0374a03  060e732b5b29e8181a18229c7b0b2b5e
# 3      b2b6027bc5c5109e529d4dc6358b12c3  259dac757896d24d7702b9acbbff3f3c
# 4      4f2d8ab171c80ec8364f7c12e35b23ad  345ecd01c38d18a9036ed96c73b8d066
# 5      879864dab9bc3047522c92c82e1212b8  4c93744516667ad3b8f1fb645a3116a4
# 6      fd826e7cf63160e536e0908c76c3f441  addec96d2e059c80c30fe6871d30d177
# 7      5e274e7a0c3809e14aba7ad5aae0d407  57b2a98a409812fe9618067b6b8ebe4f
# 8      5adf08e34b2e993982a47070956c5c65  1175e95fb47ddff9de6b2b06188f7e0d
# 9      4b7139f34592b3a31687243a302fa75b  9afe194fb833f79e300e37e580171f22
# 10     9fb35e4ed6f0a14a4977cd9aea4042bb  2a7745e1ed516b289ed9b29c7d0539a5
# 11     5aa9e4fdd4dfd20959cad2d772509598  2a46fb94aef5cbeeb850418118cee090
# ...

# %%
#위치데이터
geo = pd.read_csv("olist_geolocation_dataset.csv")
geo_seller = pd.read_csv("olist_geolocation_dataset.csv")
geo_customer = geo
geo_customer.columns.values[0] = "customer_zip_code_prefix"
geo_customer.columns.values[1] = "geo_customer_lat"
geo_customer.columns.values[2] = "geo_customer_lng"
geo_customer.columns.values[3] = "geo_customer_city"
geo_customer.columns.values[4] = "geo_customer_state"
geo_customer
#중복된 행 제거
geo_customer=geo_customer.drop_duplicates(["customer_zip_code_prefix"], keep="last")
geo_customer

geo_seller.columns.values[0] = "seller_zip_code_prefix"
geo_seller.columns.values[1] = "geo_seller_lat"
geo_seller.columns.values[2] = "geo_seller_lng"
geo_seller.columns.values[3] = "geo_seller_city"
geo_seller.columns.values[4] = "geo_seller_state"
geo_seller=geo_seller.drop_duplicates(["seller_zip_code_prefix"], keep="last")
geo_seller
# Out:
#          seller_zip_code_prefix  geo_seller_lat  geo_seller_lng  \
# 950                        1029      -23.539609      -46.632911
# 962                        1006      -23.550317      -46.636604
# 1127                       1038      -23.544340      -46.640552
# 1133                       1018      -23.551846      -46.633756
# 1156                       1022      -23.547795      -46.630238
# 1178                       1027      -23.538609      -46.629563
# 1232                       1012      -23.547678      -46.635147
# 1263                       1019      -23.552016      -46.630932
# 1295                       1041      -23.544085      -46.639786
# 1315                       1003      -23.548901      -46.637157
# 1328                       1002      -23.548551      -46.635072
# 1339                       1015      -23.547973      -46.633468
# 1346                       1033      -23.536156      -46.635650
# 1347                       1030      -23.538185      -46.632941
# ...

# %%
#상품 주문데이터
order_items=pd.read_csv("olist_order_items_dataset.csv")
order_items
#order_id의 중복 -> 제거 필요
#중복된 행 중 마지막 행만 남긴다
drop_order_items=order_items.drop_duplicates(["order_id"], keep="last")
drop_order_items
# Out:
#                                 order_id  order_item_id  \
# 0       00010242fe8c5a6d1ba2dd792cb16214              1
# 1       00018f77f2f0320c557190d7a144bdd3              1
# 2       000229ec398224ef6ca0657da4fc703e              1
# 3       00024acbcdf0a6daa1e931b038114c75              1
# 4       00042b26cf59d7ce69dfabb4e55b4fd9              1
# 5       00048cc3ae777c65dbb7d2a0634bc1ea              1
# 6       00054e8431b9d7675808bcb819fb4a32              1
# 7       000576fe39319847cbb9d288c5617fa6              1
# 8       0005a1a1728c9d785b8e2b08b904576c              1
# 9       0005f50442cb953dcd1d21e1fb923495              1
# 10      00061f2a7bc09da83e415a52dc8a4af1              1
# 11      00063b381e2406b52ad429470734ebd5              1
# 12      0006ec9db01a64e59a68b2c340bf65a7              1
# 14      0008288aa423d2a3f00fcb17cd7d8719              2
# 15      0009792311464db532ff765bf7b182ae              1
# 16      0009c9a17f916a706d71784483a5d643              1
# ...

# %%
#결제데이터
order_payments=pd.read_csv("olist_order_payments_dataset.csv")
order_payments
# Out:
#                                 order_id  payment_sequential payment_type  \
# 0       b81ef226f3fe1789b1e8b2acac839d17                   1  credit_card
# 1       a9810da82917af2d9aefd1278f1dcfa0                   1  credit_card
# 2       25e8ea4e93396b6fa0d3dd708e76c1bd                   1  credit_card
# 3       ba78997921bbcdc1373bb41e913ab953                   1  credit_card
# 4       42fdf880ba16b47b59251dd489d4441a                   1  credit_card
# 5       298fcdf1f73eb413e4d26d01b25bc1cd                   1  credit_card
# 6       771ee386b001f06208a7419e4fc1bbd7                   1  credit_card
# 7       3d7239c394a212faae122962df514ac7                   1  credit_card
# 8       1f78449c87a54faf9e96e88ba1491fa9                   1  credit_card
# 9       0573b5e23cbd798006520e1d5b4c6714                   1       boleto
# 10      d88e0d5fa41661ce03cf6cf336527646                   1  credit_card
# 11      2480f727e869fdeb397244a21b721b67                   1  credit_card
# ...

# %%
#주문 및 배송정보
orders=pd.read_csv("olist_orders_dataset.csv")
orders
# Out:
#                                order_id                       customer_id  \
# 0      e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1      53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2      47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3      949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4      ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
# 5      a4591c265e18cb1dcee52889e2d8acc3  503740e9ca751ccdda7ba28e9ab8f608
# 6      136cce7faa42fdb2cefd53fdc79a6098  ed0271e0b7da060a393796590e7b737a
# 7      6514b8ad8028c9f2cc2374ded245783f  9bdf08b4b3b52b5526ff42d37d47f222
# 8      76c6e866289321a7c93b82b54852dc33  f54a9f0e6b351c431402b8461ea51999
# 9      e69bfb5eb88e0ed6a785585b27e16dbf  31ad1d1b63eb9962463f764d4e6e0c9d
# 10     e6ce16cb79ec1d90b1da9085a6118aeb  494dded5b201313c64ed7f100595b95c
# 11     34513ce0c4fab462a55830c0989c7edb  7711cf624183d843aafe81855097bc37
# ...

# %%
#제품정보
product=pd.read_csv("olist_products_dataset.csv")
product.head()
# Out:
#                          product_id  product_category_name  \
# 0  1e9e8ef04dbcff4541ed26657ea517e5             perfumaria
# 1  3aa071139cb16b67ca9e5dea641aaa2f                  artes
# 2  96bd76ec8810374ed1b65e291975717f          esporte_lazer
# 3  cef67bcfe19066a932b7673e239eb23d                  bebes
# 4  9dc1a7de274444849c219cff195d0b71  utilidades_domesticas
#
#    product_name_lenght  product_description_lenght  product_photos_qty  \
# 0                 40.0                       287.0                 1.0
# 1                 44.0                       276.0                 1.0
# 2                 46.0                       250.0                 1.0
# 3                 27.0                       261.0                 1.0
# 4                 37.0                       402.0                 4.0
#
#    product_weight_g  product_length_cm  product_height_cm  product_width_cm
# 0             225.0               16.0               10.0              14.0
# ...

# %%
#제품 항목데이터
product_category=pd.read_csv("product_category_name_translation.csv")
product_category.head()
# Out:
#     product_category_name product_category_name_english
# 0            beleza_saude                 health_beauty
# 1  informatica_acessorios         computers_accessories
# 2              automotivo                          auto
# 3         cama_mesa_banho                bed_bath_table
# 4        moveis_decoracao               furniture_decor

# %%
#리뷰 데이터
review=pd.read_csv("olist_order_reviews_dataset.csv")
review.head()
# Out:
#                           review_id                          order_id  \
# 0  7bc2406110b926393aa56f80a40eba40  73fc7af87114b39712e6da79b0a377eb
# 1  80e641a11e56f04c1ad469d5645fdfde  a548910a1c6147796b98fdf73dbeba33
# 2  228ce5500dc1d8e020d8d1322874b6f0  f9e4b658b201a9f2ecdecbb34bed034b
# 3  e64fb393e7b32834bb789ff8bb30750e  658677c97b385a9be170737859d3511b
# 4  f7c4243c7fe1938f181bec41a392bdeb  8e6bfb81e283fa7e4f11123a3fb894f1
#
#    review_score review_comment_title  \
# 0             4                  NaN
# 1             5                  NaN
# 2             5                  NaN
# 3             5                  NaN
# 4             5                  NaN
#
#                               review_comment_message review_creation_date  \
# 0                                                NaN  2018-01-18 00:00:00
# 1                                                NaN  2018-03-10 00:00:00
# 2                                                NaN  2018-02-17 00:00:00
# ...

# %%
#판매자 데이터
seller=pd.read_csv("olist_sellers_dataset.csv")
seller
# Out:
#                              seller_id  seller_zip_code_prefix  \
# 0     3442f8959a84dea7ee197c632cb2df15                   13023
# 1     d1b65fc7debc3361ea86b5f14c68d2e2                   13844
# 2     ce3ad9de960102d0677a81f5d0bb7b2d                   20031
# 3     c0f3eea2e14555b6faeea3dd58c1b1c3                    4195
# 4     51a04a8a6bdcb23deccc82b0b80742cf                   12914
# 5     c240c4061717ac1806ae6ee72be3533b                   20920
# 6     e49c26c3edfa46d227d5121a6b6e4d37                   55325
# 7     1b938a7ec6ac5061a66a3766e0e75f90                   16304
# 8     768a86e36ad6aae3d03ee3c6433d61df                    1529
# 9     ccc4bbb5f32a6ab2b7066a4130f114e3                   80310
# 10    8cb7c5ddf41f4d506eba76e9a4702a25                   75110
# 11    a7a9b880c49781da66651ccf4ba9ac38                   13530
# 12    8bd0f31cf0a614c658f6763bd02dea69                    1222
# 13    05a48cc8859962767935ab9087417fbb                    5372
# ...

# %%
#데이터프레임 병합
mergedata1 = pd.merge(customer, orders, on="customer_id", how="right")
mergedata2 = pd.merge(mergedata1, drop_order_items, on="order_id", how="left")
mergedata3 = pd.merge(mergedata2, product, on="product_id", how="left")
mergedata4 = pd.merge(mergedata3, product_category, on="product_category_name", how="left")
mergedata5 = pd.merge(mergedata4, seller, on="seller_id", how="left")
mergedata6 = pd.merge(mergedata5, geo_customer, on="customer_zip_code_prefix", how="left")
mergedata7 = pd.merge(mergedata6, geo_seller, on="seller_zip_code_prefix", how="left")
mergedata7
#dataset = mergedata4.drop(["customer_zip_code_prefix", "product_category_name","product_description_lenght","product_photos_qty","product_weight_g","product_length_cm","product_height_cm","product_width_cm"], 1)
#dataset = dataset.drop(["customer_city", "customer_state", "order_status", "order_approved_at", "order_delivered_carrier_date", "order_estimated_delivery_date", "seller_id", "shipping_limit_date"], 1)
#dataset = pd.merge(dataset, order_payments, on="order_id", how="left")
#dataset = pd.merge(dataset, review, on="order_id", how="left")
#dataset = dataset.drop(["review_id","review_comment_title","review_comment_message","review_creation_date","review_answer_timestamp","payment_type", "product_category_name_english", "product_id", "order_id", "customer_id", "customer_unique_id", "price", "freight_value", "product_name_lenght", "payment_sequential"], 1)

from math import sin, cos, sqrt, atan2, radians
from pandas import Series, DataFrame

distance = pd.read_csv("distance.csv")

distance = pd.merge(distance, order_payments, on="order_id", how="left")
distance = pd.merge(distance, review, on="order_id", how="left")
distance

#distance.to_csv("distance.csv", index=False)
# Out:
# C:\Users\김민주\AppData\Local\conda\conda\envs\python3.7\lib\site-packages\IPython\core\interactiveshell.py:3020: DtypeWarning: Columns (2,10,47,48,57,58,67,68) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
#군집분석을 위한 데이터셋 생성
clst_dataset = pd.read_csv("dataset2.csv")
clst_dataset = clst_dataset.dropna()
clst_dataset = clst_dataset.drop(["order_purchase_timestamp","order_delivered_customer_date"],1)
clst_dataset

x = clst_dataset.drop(["review_score", "delivering_date"],1)
x
# Out:
#         order_item_id  payment_installments  payment_value
# 0                 1.0                   2.0         146.87
# 1                 1.0                   8.0         335.48
# 2                 1.0                   7.0         157.73
# 3                 1.0                   1.0         173.30
# 4                 1.0                   8.0         252.25
# 5                 1.0                   1.0         282.21
# 6                 1.0                   1.0          22.77
# 7                 1.0                   3.0          36.01
# 8                 1.0                   1.0          39.10
# 9                 1.0                   1.0         122.47
# 10                1.0                   1.0          40.40
# 11                1.0                   1.0         153.13
# 12                1.0                   1.0         117.31
# 13                1.0                   3.0          36.39
# 14                1.0                  10.0         102.47
# ...

# %%
#필요한 패키지 반입
#!pip install scipy
#!pip install sklearn
#!pip install seaborn
import pandas as pd
import numpy as np
from sklearn import model_selection
from sklearn import metrics
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt
import seaborn as sns; sns.set()
#k means clustrering 함수 생성
def kmean3d(x,y):#x=반입 데이터, y=군집의 수
    x.values
    #군집의 개수 지정
    kmeans = KMeans(n_clusters=y)
    #데이터프레임을 어레이로 변환(x.values)
    kmeans.fit(x.values)
    print("클러스터 레이블:|n{}".format(kmeans.labels_))
    y_kmeans=kmeans.predict(x.values)
    fig = plt.figure()
    #ax = fig.add_subplot(111, projection='3d')
    ax = fig.gca(projection='3d')
    #클러스터의 중심값
    centers=kmeans.cluster_centers_
    #3차원 산점도
    ax.scatter(x.values[:,0],x.values[:,1],x.values[:,2], c=y_kmeans, cmap='viridis')
    ax.set_xlabel(x.columns[0])
    ax.set_ylabel(x.columns[1])
    ax.set_zlabel(x.columns[2])
    ax.scatter(centers[:,0],centers[:,1],centers[:,2], c='black', s=10, alpha=0.75)

    plt.show()
kmean3d(x,2)

#최적의 클러스터 개수(k) 찾기
#https://m.blog.naver.com/PostView.nhn?blogId=samsjang&logNo=221017639342&proxyReferer=https%3A%2F%2Fwww.google.co.kr%2F
def elbow(x):
    sse = []
    for i in range(1, 11):
        km = KMeans(n_clusters=i, init='k-means++', random_state=0)
        km.fit(x.values)
        sse.append(km.inertia_)
    
    plt.plot(range(1,11), sse, marker='o')
    plt.xlabel("Number of Clusters")
    #SSE = 오차제곱합
    plt.ylabel("SSE : Sum of Squares Error")
    plt.show()
    
elbow(x)
# Out:
# 클러스터 레이블:|n[0 0 0 ... 0 1 0]

# %%
class KMeans:
    """k-means로 군집화 실행"""
    def __init__(self, k):
        self.k = k #군집의 개수
        self.means = None #군집의 중심값

    def classify(self, input):
        """입력 데이터에 가장 인접한 군집의 인덱스를 반환"""
        return min(range(self.k)),key=lambda i: squared_distance(input, self.means[i]))

    def train(self, inputs):
        #임의로 k개의 점을 초기 중심점으로 선택
        self.means = random.sample(inputs, self.k)
        assignments = None

        while True:
            #소속되는 군집을 다시 찾기
            new_assignments = map(self.classify, inputs)

            #소속되는 군집이 바뀌지 않았다면 종료
            if assignments == new.assignments:
                return

            #아니라면 새로운 군집을 찾기
            assignments = new_assignments

            #수정된 군집의 새로운 중심점 계산
            for i in range(self.k):
                #군집 i에 속하는 모든 데이터 탐색
                i_points = [p for p, a in zip(inputs, assignments) if a == i]

                #0으로 나누는 일이 없도록 i_points가 비어 있지 않는지 확인
                if i_points:
                    self.means[i] = vector_mean(i_points)
                    

classify(self, x2)
train(self, x2)

# %%
def squared_clustering_errors(inputs, k):
    cluster = KMeans(k)
    cluster.train(inputs)
    means = cluster.means
    assignments = map(cluster.classify, inputs)
    
    return sum(squared_distance(input, means[cluster])for input, cluster in zip(inputs, assignments))
ks = range(1, len(inputs)+1)
errors = [squared_clustering_errors(inputs, k) for k in ks]

plt.plot(ks. errors)
plt.xticks(ks)
plt.xlabel("k")
plt.ylabel("total squared error")
plt.title("Total Error vs.# of Clusters")
plt.show()

squared_clustering_errors(x2, 3)

# %%
#traing set과 test set 분할(7:3)
from sklearn.model_selection import train_test_split
train_set, test_set = train_test_split(dataset, test_size = 0.3)

train_set.shape
test_set.shape

# %%
#Expectation-Maximazation

rng = np.random.RandomState(42)
centers= [0, 4] + rng.randn(4, 2)

from sklearn.metrics import pairwise_distances_argmin
def draw_points(ax, c, factor=1):
    ax.scatter(x2.values[:,0], x2.values[:,1], c=c, cmap='viridis', s=50 * factor, alpha=0.3)
    
def draw_centers(ax, centers, factor=1, alpha=1.0):
     ax.scatter(centers[:,0], centers[:,1], c=np.arange(4), cmap='viridis', s=200 * factor, alpha=alpha)
    
     ax.scatter(centers[:,0], centers[:,1], c='black', s=50 * factor, alpha=alpha)
        
def make_ax(fig, gs):
    ax = fig.add_subplot(gs)
    ax.xaxis.set_major_formatter(plt.NullFormatter())
    ax.yaxis.set_major_formatter(plt.NullFormatter())
    return ax

fig = plt.figure(figsize=(15,4))
gs = plt.GridSpec(4, 15, left=0.02, right=0.98, bottom=0.05, top=0.95)
ax0 = make_ax(fig, gs[:4, :4])
ax0.text(0.98, 0.98, "Random Initialization", transform=ax0.transAxes, ha='right', va='top', size=16)
draw_points(ax0, 'gray', factor=2)
draw_centers(ax0, centers, factor=2)

for i in range(3):
    ax1 = make_ax(fig, gs[:2, 4 + 2 * i:6 + 2 * i])
    ax2 = make_ax(fig, gs[2:, 5 + 2 * i:7 + 2 * i])

    #E-step
    y_pred = pairwise_distances_argmin(x2.values, centers)
    draw_points(ax1, y_pred)
    draw_centers(ax1, centers)

    #M-step
    new_centers = np.array([x2.values[y_pred == i].mean(0) for i in range(4)])
    draw_points(ax2, y_pred)
    draw_centers(ax2, centers, alpha=0.3)
    draw_centers(ax2, new_centers)
    for i in range(4):
        ax2.annotate('', new_centers[i], centers[i], arrowprops=dict(arrowstyle='->', linewidth=1))

    #Finish iteration
    centers = new_centers
    ax1.text(0.95, 0.95, "E-Step", transform=ax1.transAxes, ha='right')
    ax2.text(0.95, 0.95, "M-Step", transform=ax2.transAxes, ha='right')

    #Final E-Step
    y_pred = pairwise_distances_argmin(x2.values, centers)
    axf = make_ax(fig, gs[:4, -4:])
    draw_points(axf, y_pred, factor=2)
    draw_centers(axf, centers, factor=2)
    axf.text(0.98, 0.98, "Final Clustering", transform=axf.transAxes, ha='right', va='top', size=16)

fig.savefig('figures/05.11-expectation-maximization.png')

# %%
pubg = pd.read_csv("agg_match_stats_4.csv")
pubg.head()

pubg = pubg.drop([""])

pubg.values
#군집의 개수 지정
kmeans = KMeans(n_clusters=4)
#데이터프레임을 어레이로 변환
kmeans.fit(pubg.values)
print("클러스터 레이블:|n{}".format(kmeans.labels_))
y_kmeans=kmeans.predict(pubg.values)
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
#plt.scatter(dataset.values[:,0], dataset.values[:,1], c=y_kmeans, s=30, cmap='viridis')
centers=kmeans.cluster_centers_
#plt.scatter(centers[:,0], centers[:,1], c='black', s=100, alpha=0.5)
#3차원 산점도
ax.scatter(pubg.values[:,0],pubg.values[:,1],pubg.values[:,2], c=y_kmeans, cmap='viridis')
ax.set_xlabel('Purchase Quantity')
ax.set_ylabel('Installment')
ax.set_zlabel('Payment')
ax.scatter(centers[:,0],centers[:,1],centers[:,2], c='black', s=500, alpha=0.5)

plt.show()

# %%
import statsmodels.api as sm
import statsmodels.formula.api as smf
from statsmodels.formula.api import ols, glm

# %%
distance = distance.dropna()

#reg_dataset = reg_dataset.drop(["order_purchase_timestamp","order_approved_at" ,"order_delivered_carrier_date","order_delivered_customer_date","order_estimated_delivery_date", "payment_type", "review_id", "review_creation_date" ],1)

my_formula = 'review_score ~ price + payment_value + payment_installments + product_name_lenght + product_description_lenght + product_photos_qty + product_weight_g + product_length_cm + product_height_cm + product_width_cm + customer_seller_distance'

#price	freight_value	product_category_name	product_name_lenght	product_description_lenght	product_photos_qty	product_weight_g	product_length_cm	product_height_cm	product_width_cm

#delivering_date	estimate_delivering_date	customer_seller_distance


lm = ols(my_formula, data=distance).fit()

print(lm.summary())

#dependant_variable = reg_dataset["payment_value"]
#independant_variables = reg_dataset[reg_dataset.columns.difference(['payment_value', 'type', 'in_sample'])]
#independant_variables_standardized = (independant_variables - independant_variables.mean())/independant_variables.std()
#reg_standardized = pd.concat([dependant_variable, independant_variables_standardized], axis=1)

#lm_standardized = ols(my_formula, data=reg_standardized).fit()

#independant_variables_standardized

#print(lm_standardized.summary())

# %%
#logistic regression
satisfaction = pd.read_csv("satisfaction.csv")
satisfaction = satisfaction.drop(["review_score"],1)
satisfaction = satisfaction.drop(["product_height_cm"],1)
satisfaction = satisfaction.dropna()
satisfaction

# logistic regression
cols = satisfaction.columns[1:16] # train_cols는 설명 변수
logit = sm.Logit(satisfaction['satisfaction'], satisfaction[cols]) # Survived는 목적 변수
 
# fit the model
result = logit.fit() 
 
print(result.summary()) # 분석결과 출력

from sklearn.linear_model import LogisticRegression
from sklearn import metrics
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(satisfaction[cols], satisfaction['satisfaction'], test_size=0.3, random_state=0)
logreg = LogisticRegression()

logreg.fit(X_train, y_train)

y_pred = logreg.predict(X_test)

print('Accuracy of logistic regression classifier on test set: {:.2f}'.format(logreg.score(X_test, y_test)))

from sklearn.metrics import confusion_matrix
#confusion_matrix = confusion_matrix(y_test, y_pred)
#print(confusion_matrix)

cm = pd.DataFrame(confusion_matrix(y_test, y_pred))
sns.heatmap(cm, annot=True)

from sklearn.metrics import classification_report
print(classification_report(y_test, y_pred))

from sklearn.metrics import roc_auc_score
from sklearn.metrics import roc_curve
logit_roc_auc = roc_auc_score(y_test, logreg.predict(X_test))
fpr, tpr, thresholds = roc_curve(y_test, logreg.predict_proba(X_test)[:,1])
plt.figure()
plt.plot(fpr, tpr, label='Logistic Regression (area = %0.2f)' % logit_roc_auc)
plt.plot([0, 1], [0, 1],'r--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver operating characteristic')
plt.legend(loc="lower right")
plt.savefig('Log_ROC')
plt.show()
#k-fold 교차검증
from sklearn.model_selection import cross_val_score
scores = cross_val_score(logreg, satisfaction, satisfaction['satisfaction'], cv=10)
print("교차 검증 점수: {}".format(scores))
print("교차 검증 평균 점수: {:.2f}".format(scores.mean()))

#출처: https://3months.tistory.com/28 [Deep Play]
#출처 : https://towardsdatascience.com/building-a-logistic-regression-in-python-step-by-step-becd4d56c9c8
# Out:
# Optimization terminated successfully.
#          Current function value: 0.412775
#          Iterations 9
#                            Logit Regression Results
# ...
# Dep. Variable:           satisfaction   No. Observations:               114718
# Model:                          Logit   Df Residuals:                   114703
# Method:                           MLE   Df Model:                           14
# Date:                Tue, 18 Dec 2018   Pseudo R-squ.:                  0.4044
# Time:                        12:28:39   Log-Likelihood:                -47353.
# converged:                       True   LL-Null:                       -79499.
#                                         LLR p-value:                     0.000
# ...
#                                  coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------
# ...

# %%
#random forest
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix

rf = RandomForestClassifier(n_estimators=100, oob_score=True, random_state=123456)
rf.fit(X_train, y_train)
predicted = rf.predict(X_test)
accuracy = accuracy_score(y_test, predicted)

print(f'Out-of-bag score estimate: {rf.oob_score_:.3}')
print(f'Mean accuracy score: {accuracy:.3}')

cm = pd.DataFrame(confusion_matrix(y_test, predicted))
sns.heatmap(cm, annot=True)

print("특성 중요도 : \n{}".format(rf.feature_importances_))
# Out:
# Out-of-bag score estimate: 0.957
# Mean accuracy score: 0.959
# 특성 중요도 :
# [0.00610514 0.06740983 0.06001926 0.10167621 0.06366632 0.01817981
#  0.10000309 0.0740944  0.05195022 0.15834585 0.13833056 0.07200573
#  0.01098523 0.06511288 0.01211547]

# %%
satisfaction
# Out:
#         satisfaction  order_item_id   price  freight_value  \
# 0                  1            1.0  124.99          21.88
# 1                  1            1.0  289.00          46.48
# 2                  1            1.0  139.94          17.79
# 3                  1            1.0  149.94          23.36
# 4                  1            1.0  230.00          22.25
# 5                  1            1.0  259.90          22.31
# 6                  1            1.0   14.99           7.78
# 8                  1            1.0   25.00          14.10
# 9                  1            1.0   99.90          22.57
# 10                 1            1.0   25.30          15.10
# 11                 1            1.0  129.90          23.23
# 12                 1            1.0   99.00          18.31
# 13                 0            1.0   27.99           8.40
# 14                 1            1.0   84.00          18.47
# 15                 1            1.0  129.00          40.23
# ...
